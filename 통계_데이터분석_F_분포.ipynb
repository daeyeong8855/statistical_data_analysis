# %% [markdown]
# <a href="https://colab.research.google.com/github/daeyeong8855/statistical_data_analysis/blob/main/%ED%86%B5%EA%B3%84_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D_F_%EB%B6%84%ED%8F%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

dfn = 5
dfd = 10

num_simulations = 1000
f_values = np.random.f(dfn, dfd, num_simulations)

plt.hist(f_values, bins=20,alpha=0.5)
# Out:
# (array([503., 304., 113.,  31.,  17.,  11.,   9.,   2.,   5.,   2.,   0.,
#           1.,   0.,   1.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([ 0.0284654 ,  0.90769945,  1.7869335 ,  2.66616754,  3.54540159,
#          4.42463564,  5.30386968,  6.18310373,  7.06233778,  7.94157182,
#          8.82080587,  9.70003992, 10.57927397, 11.45850801, 12.33774206,
#         13.21697611, 14.09621015, 14.9754442 , 15.85467825, 16.73391229,
#         17.61314634]),
#  <BarContainer object of 20 artists>)
